# %%
import numpy as np
import pandas as pd

# %%
df =  pd.DataFrame({'date': ['15/10/2012', '16/10/2022', '17/10/2022'],
                  'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#         date  value
# 0 2012-10-15      2
# 1 2022-10-16      3
# 2 2022-10-17      4

# %%
today = pd.to_datetime("today")
print(today)
# Out:
# 2022-03-10 04:41:31.694197

# %%
only_date= pd.to_datetime("today").date()
print(only_date)
# Out:
# 2022-03-10

# %%
only_time= pd.to_datetime("today").time()
print(only_time)
# Out:
# 05:08:25.153240

# %%
df =  pd.DataFrame({'date': ['10/03/2022'],'Value':[2]})
#df=pd.DataFrame({'time':['9:12:25.1098']},'Value':[3])
df['date']=pd.to_datetime(df['date'])
#df['time']=pd.to_datetime(df['time'])
df
# Out:
#         date  Value
# 0 2022-10-03      2

# %%
df=pd.DataFrame({'time':['9:20:13.1327387'],'value':[1]})
df['time']=pd.to_datetime(df['time'])
df
# Out:
#                         time  value
# 0 2022-03-10 09:20:13.132738      1
